# %% [markdown]
# <h1>2. Applying ResNet pre-trained model </h1>

# %% [markdown]
# * We will not include the top layer of ResNet model.
# * Instead of top layer, we will add a dense layer with four units and with softmax activation function.
# * We will take the imagenet weight as weight initialization and will not freeze any layer.

# %%
import matplotlib.pyplot as plt
from keras.applications.resnet50 import ResNet50, preprocess_input
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Input
from keras.models import Model
from keras.layers import Dense
from keras.optimizers import Adam
#from generator import DataGenerator
import keras
from keras.callbacks import ModelCheckpoint
# Out:
# Using TensorFlow backend.

# %%
# Data augmentation
labels = os.listdir('../input/oct2017/OCT2017 /train/')
train_datagen = ImageDataGenerator(samplewise_center=True, 
                              samplewise_std_normalization=True, 
                              horizontal_flip = True, 
                              vertical_flip = False, 
                              height_shift_range= 0.05, 
                              width_shift_range=0.1, 
                              rotation_range=15, 
                              zoom_range=0.15,
                                   validation_split=0.2)

# %%
IMG_SIZE = 224
batch_size = 16
train_data_dir = '../input/oct2017/OCT2017 /train'
validation_data_dir = '../input/oct2017/OCT2017 /val'
train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(IMG_SIZE , IMG_SIZE),
    batch_size=16,
    subset='training',
    class_mode='categorical')
valid_X, valid_Y = next(train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(IMG_SIZE , IMG_SIZE),
    batch_size=4000,
    subset='validation',
    class_mode='categorical'))
# Out:
# Found 66788 images belonging to 4 classes.
# Found 16696 images belonging to 4 classes.

# %%
t_x, t_y = next(train_generator)
fig, m_axs = plt.subplots(4, 4, figsize = (16, 16))
for (c_x, c_y, c_ax) in zip(t_x, t_y, m_axs.flatten()):
    c_ax.imshow(c_x[:,:,0], cmap = 'bone')
    c_ax.set_title(', '.join([n_class for n_class, n_score in zip(labels, c_y) 
                             if n_score>0.5]))
    c_ax.axis('off')

# %%
# Defining ResNet model
def resnet_model():
    img_in = Input(t_x.shape[1:])              #input of model 
    model = ResNet50(include_top= False , # remove  the 3 fully-connected layers at the top of the network
                weights='imagenet',      # pre train weight 
                input_tensor= img_in, 
                input_shape= t_x.shape[1:],
                pooling ='avg') 
    x = model.output  
    predictions = Dense(4, activation="softmax", name="predictions")(x)    # fuly connected layer for predict class 
    model = Model(inputs=img_in, outputs=predictions)
    return model

# %%
# compiling model
model = resnet_model()
model.compile(optimizer = 'adam', loss = 'categorical_crossentropy',
                           metrics = ['accuracy'])
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.2/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94658560/94653016 [==============================] - 1s 0us/step

# %%
# creating checkpoint
filepath="weights.best.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

# %%
# training model
history = model.fit_generator(train_generator, 
                                  steps_per_epoch=100,
                                  validation_data = (valid_X,valid_Y), 
                                  epochs = 30,
                                  callbacks=callbacks_list)
# Out:
# Epoch 1/30
# 100/100 [==============================] - 106s 1s/step - loss: 1.4786 - acc: 0.6444 - val_loss: 5.6295 - val_acc: 0.3245
#
# Epoch 00001: val_acc improved from -inf to 0.32450, saving model to weights.best.hdf5
# Epoch 2/30
# 100/100 [==============================] - 90s 899ms/step - loss: 1.2365 - acc: 0.6350 - val_loss: 8.7349 - val_acc: 0.4530
#
# Epoch 00002: val_acc improved from 0.32450 to 0.45300, saving model to weights.best.hdf5
# Epoch 3/30
# 100/100 [==============================] - 90s 898ms/step - loss: 1.0185 - acc: 0.6937 - val_loss: 1.6013 - val_acc: 0.6833
#
# Epoch 00003: val_acc improved from 0.45300 to 0.68325, saving model to weights.best.hdf5
# Epoch 4/30
# 100/100 [==============================] - 91s 907ms/step - loss: 0.7935 - acc: 0.7194 - val_loss: 1.9742 - val_acc: 0.5425
#
# Epoch 00004: val_acc did not improve from 0.68325
# Epoch 5/30
# 100/100 [==============================] - 90s 898ms/step - loss: 0.6243 - acc: 0.7812 - val_loss: 1.0668 - val_acc: 0.7143
#
# Epoch 00005: val_acc improved from 0.68325 to 0.71425, saving model to weights.best.hdf5
# Epoch 6/30
# 100/100 [==============================] - 90s 899ms/step - loss: 0.6737 - acc: 0.7662 - val_loss: 0.7163 - val_acc: 0.7495
#
# Epoch 00006: val_acc improved from 0.71425 to 0.74950, saving model to weights.best.hdf5
# Epoch 7/30
# 100/100 [==============================] - 90s 899ms/step - loss: 0.4597 - acc: 0.8462 - val_loss: 0.5525 - val_acc: 0.8185
#
# Epoch 00007: val_acc improved from 0.74950 to 0.81850, saving model to weights.best.hdf5
# Epoch 8/30
# 100/100 [==============================] - 90s 896ms/step - loss: 0.4598 - acc: 0.8425 - val_loss: 0.8550 - val_acc: 0.6827
#
# Epoch 00008: val_acc did not improve from 0.81850
# Epoch 9/30
# 100/100 [==============================] - 90s 897ms/step - loss: 0.3829 - acc: 0.8738 - val_loss: 0.3981 - val_acc: 0.8762
#
# Epoch 00009: val_acc improved from 0.81850 to 0.87625, saving model to weights.best.hdf5
# Epoch 10/30
# 100/100 [==============================] - 90s 899ms/step - loss: 0.3815 - acc: 0.8706 - val_loss: 0.4028 - val_acc: 0.8630
#
# Epoch 00010: val_acc did not improve from 0.87625
# Epoch 11/30
# 100/100 [==============================] - 90s 895ms/step - loss: 0.4065 - acc: 0.8606 - val_loss: 1.4141 - val_acc: 0.7135
#
# Epoch 00011: val_acc did not improve from 0.87625
# Epoch 12/30
# 100/100 [==============================] - 90s 897ms/step - loss: 0.3642 - acc: 0.8719 - val_loss: 1.0523 - val_acc: 0.6412
#
# Epoch 00012: val_acc did not improve from 0.87625
# Epoch 13/30
# 100/100 [==============================] - 90s 897ms/step - loss: 0.3269 - acc: 0.8906 - val_loss: 0.4008 - val_acc: 0.8870
#
# Epoch 00013: val_acc improved from 0.87625 to 0.88700, saving model to weights.best.hdf5
# Epoch 14/30
# 100/100 [==============================] - 90s 898ms/step - loss: 0.3653 - acc: 0.8762 - val_loss: 0.4968 - val_acc: 0.8380
#
# Epoch 00014: val_acc did not improve from 0.88700
# Epoch 15/30
# 100/100 [==============================] - 90s 896ms/step - loss: 0.3203 - acc: 0.8962 - val_loss: 0.3011 - val_acc: 0.9040
#
# Epoch 00015: val_acc improved from 0.88700 to 0.90400, saving model to weights.best.hdf5
# Epoch 16/30
# 100/100 [==============================] - 90s 898ms/step - loss: 0.3582 - acc: 0.8713 - val_loss: 1.5607 - val_acc: 0.7205
#
# Epoch 00016: val_acc did not improve from 0.90400
# Epoch 17/30
# 100/100 [==============================] - 90s 898ms/step - loss: 0.3317 - acc: 0.8981 - val_loss: 0.3275 - val_acc: 0.8932
#
# Epoch 00017: val_acc did not improve from 0.90400
# Epoch 18/30
# 100/100 [==============================] - 90s 896ms/step - loss: 0.2704 - acc: 0.9125 - val_loss: 0.6811 - val_acc: 0.7662
#
# Epoch 00018: val_acc did not improve from 0.90400
# Epoch 19/30
# 100/100 [==============================] - 90s 897ms/step - loss: 0.3421 - acc: 0.8794 - val_loss: 0.4712 - val_acc: 0.8640
#
# Epoch 00019: val_acc did not improve from 0.90400
# Epoch 20/30
# 100/100 [==============================] - 90s 897ms/step - loss: 0.2856 - acc: 0.9100 - val_loss: 0.6034 - val_acc: 0.8125
#
# Epoch 00020: val_acc did not improve from 0.90400
# Epoch 21/30
# 100/100 [==============================] - 90s 897ms/step - loss: 0.3030 - acc: 0.9087 - val_loss: 0.3223 - val_acc: 0.8920
#
# Epoch 00021: val_acc did not improve from 0.90400
# Epoch 22/30
# 100/100 [==============================] - 90s 897ms/step - loss: 0.2949 - acc: 0.9106 - val_loss: 0.3289 - val_acc: 0.8968
#
# Epoch 00022: val_acc did not improve from 0.90400
# Epoch 23/30
# 100/100 [==============================] - 90s 899ms/step - loss: 0.2974 - acc: 0.9069 - val_loss: 0.3266 - val_acc: 0.8940
#
# Epoch 00023: val_acc did not improve from 0.90400
# Epoch 24/30
# 100/100 [==============================] - 90s 899ms/step - loss: 0.3092 - acc: 0.9006 - val_loss: 0.4627 - val_acc: 0.8795
#
# Epoch 00024: val_acc did not improve from 0.90400
# Epoch 25/30
# 100/100 [==============================] - 90s 896ms/step - loss: 0.2985 - acc: 0.9062 - val_loss: 0.2669 - val_acc: 0.9160
#
# Epoch 00025: val_acc improved from 0.90400 to 0.91600, saving model to weights.best.hdf5
# Epoch 26/30
# 100/100 [==============================] - 90s 899ms/step - loss: 0.2774 - acc: 0.9119 - val_loss: 0.2647 - val_acc: 0.9137
#
# Epoch 00026: val_acc did not improve from 0.91600
# Epoch 27/30
# 100/100 [==============================] - 90s 900ms/step - loss: 0.2633 - acc: 0.9119 - val_loss: 0.3292 - val_acc: 0.9130
#
# Epoch 00027: val_acc did not improve from 0.91600
# Epoch 28/30
# 100/100 [==============================] - 90s 898ms/step - loss: 0.2938 - acc: 0.9069 - val_loss: 0.2764 - val_acc: 0.9140
#
# Epoch 00028: val_acc did not improve from 0.91600
# Epoch 29/30
# 100/100 [==============================] - 90s 897ms/step - loss: 0.3128 - acc: 0.8912 - val_loss: 0.5335 - val_acc: 0.8057
#
# Epoch 00029: val_acc did not improve from 0.91600
# Epoch 30/30
# 100/100 [==============================] - 90s 898ms/step - loss: 0.2719 - acc: 0.9075 - val_loss: 0.2801 - val_acc: 0.9195
#
# Epoch 00030: val_acc improved from 0.91600 to 0.91950, saving model to weights.best.hdf5

# %%
# loading the model with best weight
model = resnet_model()
model.load_weights(filepath)

# %%
# creating test data
test_X, test_Y = next(train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(IMG_SIZE , IMG_SIZE),
    batch_size=8000,
    subset='validation',
    class_mode='categorical'))
# Out:
# Found 16696 images belonging to 4 classes.

# %%
# predicting y value
y_pred = model.predict(test_X)

# %%
pred_class = []
for i in range(len(y_pred)):
    pred_class.append(np.argmax(y_pred[i]))

# %%
actual_class = []
for i in range(len(test_Y)):
    actual_class.append(np.argmax(test_Y[i]))

# %%
# accuracy score
from sklearn.metrics import accuracy_score
print('accuracy = ',accuracy_score(pred_class,actual_class))
# Out:
# accuracy =  0.914375

# %%
# defining confusion matrix
import seaborn as sns
from sklearn.metrics import confusion_matrix
def plot_confusion_matrix(test_y, predict_y):
    C = confusion_matrix(test_y, predict_y)
    # C = 9,9 matrix, each cell (i,j) represents number of points of class i are predicted class j
    
    A =(((C.T)/(C.sum(axis=1))).T)
    #divid each element of the confusion matrix with the sum of elements in that column
    
    # C = [[1, 2],
    #     [3, 4]]
    # C.T = [[1, 3],
    #        [2, 4]]
    # C.sum(axis = 1)  axis=0 corresonds to columns and axis=1 corresponds to rows in two diamensional array
    # C.sum(axix =1) = [[3, 7]]
    # ((C.T)/(C.sum(axis=1))) = [[1/3, 3/7]
    #                           [2/3, 4/7]]

    # ((C.T)/(C.sum(axis=1))).T = [[1/3, 2/3]
    #                           [3/7, 4/7]]
    # sum of row elements = 1
    
    B =(C/C.sum(axis=0))
    #divid each element of the confusion matrix with the sum of elements in that row
    # C = [[1, 2],
    #     [3, 4]]
    # C.sum(axis = 0)  axis=0 corresonds to columns and axis=1 corresponds to rows in two diamensional array
    # C.sum(axix =0) = [[4, 6]]
    # (C/C.sum(axis=0)) = [[1/4, 2/6],
    #                      [3/4, 4/6]] 
    
    labels = [0,1,2,3]
    # representing A in heatmap format
    print("-"*20, "Confusion matrix", "-"*20)
    plt.figure(figsize=(20,7))
    sns.heatmap(C, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()

    print("-"*20, "Precision matrix (Columm Sum=1)", "-"*20)
    plt.figure(figsize=(20,7))
    sns.heatmap(B, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()
    
    # representing B in heatmap format
    print("-"*20, "Recall matrix (Row sum=1)", "-"*20)
    plt.figure(figsize=(20,7))
    sns.heatmap(A, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()

# %%
plot_confusion_matrix(actual_class,pred_class)
# Out:
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------
